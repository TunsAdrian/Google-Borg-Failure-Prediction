# %%
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd

# %%
jobs_feature_data = {
    'Feature': ['Scheduling Class', 'Scheduling Class', 'Scheduling Class', 'Scheduling Class',
                'Priority', 'Priority', 'Priority', 'Priority',
                'CPU', 'CPU', 'CPU', 'CPU',
                'Memory', 'Memory', 'Memory', 'Memory'],

    'Model': ['Decision Tree', 'Random Forest', 'Gradient Boosting', 'Logistic Regression',
              'Decision Tree', 'Random Forest', 'Gradient Boosting', 'Logistic Regression',
              'Decision Tree', 'Random Forest', 'Gradient Boosting', 'Logistic Regression',
              'Decision Tree', 'Random Forest', 'Gradient Boosting', 'Logistic Regression'],

    'Importance': [0.17, 0.16, 0.09, 0.29,
                   0.22, 0.09, 0.14, 0.13,
                   0.18, 0.20, 0.07, 0.59,
                   0.38, 0.22, 0.44, 0.0]
}

jobs_feature_df = pd.DataFrame(jobs_feature_data)

plt.figure(figsize=(10, 6))
sb.barplot(data=jobs_feature_df, x='Feature', y='Importance', hue='Model', palette=sb.color_palette('muted'))
plt.xlabel('')
plt.ylabel('')
plt.legend(title='Model')
plt.show()

# %%
tasks_feature_data = {
    'Feature': ['Scheduling Class', 'Scheduling Class', 'Scheduling Class', 'Scheduling Class',
                'Priority', 'Priority', 'Priority', 'Priority',
                'CPU', 'CPU', 'CPU', 'CPU',
                'Memory', 'Memory', 'Memory', 'Memory'],

    'Model': ['Decision Tree', 'Random Forest', 'Gradient Boosting', 'Logistic Regression',
              'Decision Tree', 'Random Forest', 'Gradient Boosting', 'Logistic Regression',
              'Decision Tree', 'Random Forest', 'Gradient Boosting', 'Logistic Regression',
              'Decision Tree', 'Random Forest', 'Gradient Boosting', 'Logistic Regression'],

    'Importance': [0.04, 0.17, 0.03, 0.48,
                   0.35, 0.22, 0.26, 0.0,
                   0.0, 0.01, 0.0, 0.0,
                   0.49, 0.38, 0.39, 0.52]
}

tasks_feature_df = pd.DataFrame(tasks_feature_data)

plt.figure(figsize=(10, 6))
sb.barplot(data=tasks_feature_df, x='Feature', y='Importance', hue='Model', palette=sb.color_palette('muted'))
plt.xlabel('')
plt.ylabel('')
plt.legend(title='Model')
plt.show()
